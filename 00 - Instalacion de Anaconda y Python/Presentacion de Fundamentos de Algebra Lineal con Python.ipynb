# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

data = plt.imread(".\\imagenes\\anaconda.captura.create.png")
plt.imshow(data)
plt.show()

# %%
# Una imagen de la fotografa Frida Bredesen de una Cebra
imagen = plt.imread(".\\imagenes\\imagen_ejemplo_frida_bredesen.jpg", format="jpeg")
plt.imshow(imagen)

# %%
# Podemos pensar a la imagen como 3 matrices, una para cada canal con valores que van de 0 a 255.
# Si tuvieramos una imagen blanco y negro, solo tendriamos 1 matriz. 
print(imagen.shape)
print(imagen)
# Out:
# (3456L, 3693L, 3L)
# [[[236 236 236]
#   [236 236 236]
#   [235 235 235]
#   ...,
#   [239 239 239]
#   [239 239 239]
#   [239 239 239]]
#
#  [[236 236 236]
#   [236 236 236]
#   [235 235 235]
#   ...,
#   [239 239 239]
#   [239 239 239]
#   [239 239 239]]
#
#  [[236 236 236]
#   [236 236 236]
#   [235 235 235]
#   ...,
#   [238 238 238]
#   [238 238 238]
#   [238 238 238]]
#
#  ...,
#  [[217 217 217]
#   [216 216 216]
#   [216 216 216]
#   ...,
#   [197 197 197]
#   [196 196 196]
#   [194 194 194]]
#
#  [[216 216 216]
#   [216 216 216]
#   [216 216 216]
#   ...,
#   [196 196 196]
#   [195 195 195]
#   [193 193 193]]
#
#  [[216 216 216]
#   [216 216 216]
#   [216 216 216]
#   ...,
#   [195 195 195]
#   [195 195 195]
#   [193 193 193]]]
