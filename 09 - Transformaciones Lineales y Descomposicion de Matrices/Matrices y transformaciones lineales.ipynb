# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

# %%
# En una de las clases anterior (agregar referencia a la clase que corresponda) te conte que podiamos pensar
# las matrices como transformaciones lineales, que despues profundizariamos en este tema. Ya avanzamos mucho
# Has aprendido nuevos conceptos y ahora estas listo para dar el siguiente paso

# Tenemos matrices que al aplicarlas generan una rotacion del vector al que se lo aplicamos, o sea como ya
# vimos le decimos aplicar a multiplicar por la matriz y obtener un resultado

# %%
# Veamos un ejemplo de estas matrices
A = np.array([[-1,3],[2, -2]])
print(A)
# Out:
# [[-1  3]
#  [ 2 -2]]

# %%
vector = np.array([[2], [1]])
print(vector)
# Out:
# [[2]
#  [1]]

# %%
def plotVectors(vecs, cols, alpha=1):
    """
    Plot set of vectors.

    Parameters
    ----------
    vecs : array-like
        Coordinates of the vectors to plot. Each vectors is in an array. For
        instance: [[1, 3], [2, 2]] can be used to plot 2 vectors.
    cols : array-like
        Colors of the vectors. For instance: ['red', 'blue'] will display the
        first vector in red and the second in blue.
    alpha : float
        Opacity of vectors

    Returns:

    fig : instance of matplotlib.figure.Figure
        The figure of the vectors
    """
    plt.axvline(x=0, color='#A9A9A9', zorder=0)
    plt.axhline(y=0, color='#A9A9A9', zorder=0)

    for i in range(len(vecs)):
        if (isinstance(alpha, list)):
            alpha_i = alpha[i]
        else:
            alpha_i = alpha
        x = np.concatenate([[0,0],vecs[i]])
        plt.quiver([x[0]],
                   [x[1]],
                   [x[2]],
                   [x[3]],
                   angles='xy', scale_units='xy', scale=1, color=cols[i],
                  alpha=alpha_i)

# %%
print(vector.flatten())
plotVectors([vector.flatten()], cols=['blue'])
plt.ylim(-1, 4)
plt.xlim(-1, 4)
# Out:
# [2 1]
# <img src="data:image/png;base64,..." width="640">
# (-1, 4)

# %%
vector_transformado = A.dot(vector)
print(vector_transformado)

plotVectors([vector.flatten(), vector_transformado.flatten()], cols=['blue', 'orange'])
plt.ylim(-1, 4)
plt.xlim(-1, 4)
# Out:
# [[1]
#  [2]]
# <img src="data:image/png;base64,..." width="640">
# (-1, 4)
